# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Market_Basket_Optimisation.csv",header=None)

# %%
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
transactions=[]#empty list
for i in range(0,7501):#this for loop iterates vertically
    transactions.append([str(data.values[i,j]) for j in range(0,20)])#iterates horizontlly

# %%
from apyori import apriori
rules=apriori(transactions=transactions,min_support=0.003,min_length=2,max_length=2)

# %%
results=list(rules)

# %%
results
# Out:
# []

# %%
def inspect(result):
    lhs         = [tuple(result[2][0][0])[0] for result in result]
    rhs         = [tuple(result[2][0][1])[0] for result in result]
    supports    = [result[1] for result in result]
    return list(zip(lhs, rhs, supports))
resultsinDataFrame = pd.DataFrame(inspect(result), columns = ['prod 1', 'prod 2','Support'])

# %%
resultsinDataFrame
# Out:
# Empty DataFrame
# Columns: [prod 1, prod 2, Support]
# Index: []

# %%
resultsinDataFrame.nlargest(n=10,columns='Support')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-66a12843ae06> in <module>
# ----> 1 resultsinDataFrame.nlargest(n=10,columns='Support')
#
# F:\anaconda\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    5194         Brunei      434000    12128      BN
#    5195         """
# -> 5196         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5197
#    5198     def nsmallest(self, n, columns, keep="first"):
#
# F:\anaconda\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1121
#    1122     def nlargest(self):
# -> 1123         return self.compute("nlargest")
#    1124
#    1125     def nsmallest(self):
#
# F:\anaconda\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1245                         "Column {column!r} has dtype {dtype}, cannot use method "
# ...
